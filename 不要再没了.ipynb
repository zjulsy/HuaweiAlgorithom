# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,5

# %%
data = np.loadtxt('data_total_12345_array.txt')
print(data.shape)
data = data.astype(np.int16)
print(data.dtype)
# Out:
# (150, 15)
# int16

# %%
for i in range(15):
    plt.plot(data[:,i],'*')
    plt.title('type'+str(i+1))
    plt.show()
